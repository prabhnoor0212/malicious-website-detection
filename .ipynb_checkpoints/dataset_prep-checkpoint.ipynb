# %%
import re
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import pandas as pd

# %%
import googlesearch

# %%
def checkAWSRankings(url):
    try:
        lnk = 'https://www.alexa.com/siteinfo/'+url
        rc = BeautifulSoup(urlopen(lnk), 'html.parser')
        val = (rc.find('strong', class_= 'metrics-data align-vmiddle').text)
    except:
        val = "E"
    print(val)
    return val

# %%
def checkSubdomains(domain):

    return len(domain.split('.'))

# %%
data_df = pd.read_csv('dataset.csv',header= None)

# %%
data_df.head()
# Out:
#                                                   0  1   2   3   4   5   6   \
# 0  https://locking-app-adverds.000webhostapp.com/...  1  -1  -1   1   1  -1
# 1  https://mxtoolbox.com/public/upgradev2.aspx?ps...  0  -1  -1  -1  -1  -1
# 2       http://parolishop.com.br/questionreviews.htm  0  -1  -1  -1  -1  -1
# 3  http://innovate.ieee.org/innovate/35675?lt=xpl...  1  -1  -1  -1  -1  -1
# 4  http://ietbhaddal.edu.in/bb.mobile/mobile/inde...  0  -1  -1  -1  -1  -1
#
#    7   8   9    10
# 0  -1  -1  -1  yes
# 1  -1  -1  -1   no
# 2  -1  -1  -1  yes
# 3  -1  -1  -1   no
# 4   1  -1  -1  yes

# %%
url_names_arr = data_df[0].tolist()

# %%
dots = (list(map(checkSubdomains, url_names_arr)))

# %%
dots_df = pd.DataFrame(dots,columns=['SubDomains'])

# %%
dots_df.head()
# Out:
#    SubDomains
# 0           4
# 1           8
# 2           4
# 3           4
# 4           5

# %%
data_df = pd.concat([data_df, dots_df],axis=1, ignore_index=True)

# %%
data_df.head()
# Out:
#                                                   0  1   2   3   4   5   6   \
# 0  https://locking-app-adverds.000webhostapp.com/...  1  -1  -1   1   1  -1
# 1  https://mxtoolbox.com/public/upgradev2.aspx?ps...  0  -1  -1  -1  -1  -1
# 2       http://parolishop.com.br/questionreviews.htm  0  -1  -1  -1  -1  -1
# 3  http://innovate.ieee.org/innovate/35675?lt=xpl...  1  -1  -1  -1  -1  -1
# 4  http://ietbhaddal.edu.in/bb.mobile/mobile/inde...  0  -1  -1  -1  -1  -1
#
#    7   8   9    10  11
# 0  -1  -1  -1  yes   4
# 1  -1  -1  -1   no   8
# 2  -1  -1  -1  yes   4
# 3  -1  -1  -1   no   4
# 4   1  -1  -1  yes   5
